# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Selected epoch: 19 (min val_loss)
# Valid @ sel —  MAE: 0.09242 | RMSE: 0.1313 (scaled)
# Train @ sel —  MAE: 0.1334  | RMSE: 0.1719 (scaled)

# %% [markdown]
# ### Now we'll demonstrate the model's predictive power on the last 2 weeks of the test samples

# %%
def evaluate_on_test(
    model,
    *,
    target_scaler=None,          # pass your y scaler here if you want original units
    report_in_scaled=True,       # set False to invert to original units
    unit_scaled="(scaled)",
    unit_original="MW",          # or "MWh" if your target is energy, not power
    plot_last_hours=24*7,
):
    """
    Evaluate on X_test/y_test and plot the last `plot_last_hours` predictions.
    Supports horizon=1 and direct multi-output (H>1).
    """
    # 1) Predict
    y_pred = model.predict(X_test, verbose=0)         # (n_windows, H) or (n_windows, 1)
    if y_pred.ndim == 1:
        y_pred = y_pred[:, None]
    H = y_pred.shape[1]

    # 2) Choose units (scaled vs original)
    def maybe_invert(arr):
        if report_in_scaled or target_scaler is None:
            return arr
        # Need to handle both (samples,) and (samples, horizon) shapes
        original_shape = arr.shape
        a = np.asarray(arr).reshape(-1, 1)
        inverted = target_scaler.inverse_transform(a)
        return inverted.reshape(original_shape)


    # 3) Build comparable arrays for metrics
    # y_test matches y_pred shape: (n_windows, H)
    y_true = y_test

    y_true_u = maybe_invert(y_true)
    y_pred_u = maybe_invert(y_pred)

    # Calculate error per element across all windows and horizons
    err = y_pred_u - y_true_u
    rmse_avg = float(np.sqrt(np.mean(err**2)))
    mae_avg  = float(np.mean(np.abs(err)))


    if H > 1:
        # per-horizon
        mae_per_h  = np.mean(np.abs(y_true_u - y_pred_u), axis=0)
        rmse_per_h = np.sqrt(np.mean((y_true_u - y_pred_u)**2, axis=0))

    # 4) Prepare a single timeline for plotting
    def stitch_direct_predictions(yhat):
        """Average overlaps for direct multi-step predictions."""
        n, HH = yhat.shape
        total = n + HH - 1
        out = np.zeros(total, dtype=float)
        cnt = np.zeros(total, dtype=float)
        for i in range(n):
            out[i:i+HH] += yhat[i]
            cnt[i:i+HH] += 1.0
        return out / np.maximum(cnt, 1.0)

    # Choose units for plotting
    unit = unit_scaled if (report_in_scaled or target_scaler is None) else unit_original

    if H == 1:
        y_true_t = maybe_invert(y_true.ravel())
        y_pred_t = maybe_invert(y_pred.ravel())
    else:
        # stitch both for a continuous timeline
        y_pred_t = stitch_direct_predictions(maybe_invert(y_pred))
        y_true_t = stitch_direct_predictions(maybe_invert(y_true))


    # 5) Print summary
    print(f"Test RMSE (avg over all steps): {rmse_avg:,.3f} {unit}")
    print(f"Test  MAE (avg over all steps): {mae_avg:,.3f} {unit}")
    if H > 1:
        print("Per-horizon (0 = 1-step ahead):")
        print("  MAE :", np.round(mae_per_h, 3))
        print("  RMSE:", np.round(rmse_per_h, 3))

    # 6) Plot last N hours
    N = min(plot_last_hours, len(y_true_t))
    plt.figure(figsize=(14, 6))
    plt.title("Test — Last 7 Days: Truth vs Forecast")
    plt.plot(y_true_t[-N:], label="Truth")
    plt.plot(y_pred_t[-N:], label="Predicted", linestyle="--")
    plt.xlabel("Hour")
    plt.ylabel(unit)
    plt.grid(True, axis='y', linestyle=':', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Problem One — Exploring Lookback and Horizon
#
# Experiment with different combinations of `lookback` and `horizon` values.
# For example, you might double the lookback window (e.g., from 1 week to 2 weeks) or extend the prediction horizon to 24 hours.
#
# After each change:
# - Retrain your model.
# - Use `evaluate_on_test(...)` to visualize the extended 2-week prediction.
# - Compare validation and test MAE/RMSE across experiments.
# - Answer the graded questions.
#
# > *Note:* You’ll need to adjust the data-preparation cell above to rebuild the training, validation, and testing sets with the new parameters.

# %%
two_week_lookback_model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

# Train baseline model with different lookback and horizon
train_and_test(two_week_lookback_model,title="Baseline Model w/ 2 week window",verbose=1)

# Evaluate the newly trained model
evaluate_on_test(two_week_lookback_model, plot_last_hours=24*7)
# Out:
# Baseline Model w/ 2 week window
#
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.7958 - mae: 0.7428 - rmse: 0.8898 - val_loss: 0.3918 - val_mae: 0.5332 - val_rmse: 0.6259
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3910 - mae: 0.5338 - rmse: 0.6248 - val_loss: 0.3518 - val_mae: 0.4896 - val_rmse: 0.5931
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3109 - mae: 0.4764 - rmse: 0.5573 - val_loss: 0.2651 - val_mae: 0.4111 - val_rmse: 0.5148
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2456 - mae: 0.4182 - rmse: 0.4952 - val_loss: 0.1433 - val_mae: 0.3011 - val_rmse: 0.3786
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1700 - mae: 0.3433 - rmse: 0.4121 - val_loss: 0.0911 - val_mae: 0.2523 - val_rmse: 0.3018
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1109 - mae: 0.2682 - rmse: 0.3330 - val_loss: 0.0603 - val_mae: 0.2080 - val_rmse: 0.2457
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0897 - mae: 0.2415 - rmse: 0.2995 - val_loss: 0.0489 - val_mae: 0.1813 - val_rmse: 0.2211
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0755 - mae: 0.2160 - rmse: 0.2747 - val_loss: 0.0544 - val_mae: 0.1841 - val_rmse: 0.2333
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0616 - mae: 0.1961 - rmse: 0.2481 - val_loss: 0.0426 - val_mae: 0.1593 - val_rmse: 0.2063
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0559 - mae: 0.1878 - rmse: 0.2364 - val_loss: 0.0426 - val_mae: 0.1564 - val_rmse: 0.2065
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0540 - mae: 0.1835 - rmse: 0.2324 - val_loss: 0.0374 - val_mae: 0.1454 - val_rmse: 0.1934
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0496 - mae: 0.1751 - rmse: 0.2226 - val_loss: 0.0340 - val_mae: 0.1372 - val_rmse: 0.1844
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0477 - mae: 0.1711 - rmse: 0.2183 - val_loss: 0.0312 - val_mae: 0.1294 - val_rmse: 0.1766
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0406 - mae: 0.1572 - rmse: 0.2015 - val_loss: 0.0312 - val_mae: 0.1279 - val_rmse: 0.1766
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0383 - mae: 0.1521 - rmse: 0.1956 - val_loss: 0.0300 - val_mae: 0.1250 - val_rmse: 0.1732
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0359 - mae: 0.1496 - rmse: 0.1895 - val_loss: 0.0308 - val_mae: 0.1271 - val_rmse: 0.1755
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0374 - mae: 0.1504 - rmse: 0.1933 - val_loss: 0.0284 - val_mae: 0.1208 - val_rmse: 0.1687
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0348 - mae: 0.1452 - rmse: 0.1863 - val_loss: 0.0238 - val_mae: 0.1057 - val_rmse: 0.1543
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0336 - mae: 0.1401 - rmse: 0.1834 - val_loss: 0.0282 - val_mae: 0.1190 - val_rmse: 0.1679
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0331 - mae: 0.1395 - rmse: 0.1819 - val_loss: 0.0249 - val_mae: 0.1093 - val_rmse: 0.1580
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0311 - mae: 0.1348 - rmse: 0.1763 - val_loss: 0.0283 - val_mae: 0.1192 - val_rmse: 0.1681
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0333 - mae: 0.1419 - rmse: 0.1823 - val_loss: 0.0226 - val_mae: 0.1014 - val_rmse: 0.1504
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0282 - mae: 0.1289 - rmse: 0.1679 - val_loss: 0.0247 - val_mae: 0.1069 - val_rmse: 0.1571
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0278 - mae: 0.1303 - rmse: 0.1666 - val_loss: 0.0262 - val_mae: 0.1114 - val_rmse: 0.1618
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0295 - mae: 0.1313 - rmse: 0.1717 - val_loss: 0.0226 - val_mae: 0.1021 - val_rmse: 0.1504
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0281 - mae: 0.1293 - rmse: 0.1675 - val_loss: 0.0233 - val_mae: 0.1025 - val_rmse: 0.1526
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0257 - mae: 0.1263 - rmse: 0.1602 - val_loss: 0.0238 - val_mae: 0.1040 - val_rmse: 0.1543
# Epoch 27: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Selected epoch: 25 (min val_loss)
# Valid @ sel —  MAE: 0.1021 | RMSE: 0.1504 (scaled)
# Train @ sel —  MAE: 0.1305  | RMSE: 0.1708 (scaled)
# Test RMSE (avg over all steps): 0.107 (scaled)
# Test  MAE (avg over all steps): 0.088 (scaled)

# %%
hour_24_horizon_model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

# Train baseline model with different lookback and horizon
train_and_test(hour_24_horizon_model,title="Baseline Model w/ 24 hour horizon",verbose=1)

# Evaluate the newly trained model
evaluate_on_test(hour_24_horizon_model, plot_last_hours=24*7)
# Out:
# Baseline Model w/ 24 hour horizon
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.9014 - mae: 0.7793 - rmse: 0.9491 - val_loss: 0.9028 - val_mae: 0.7733 - val_rmse: 0.9501
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6376 - mae: 0.6528 - rmse: 0.7983 - val_loss: 0.5434 - val_mae: 0.6066 - val_rmse: 0.7372
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5142 - mae: 0.5925 - rmse: 0.7171 - val_loss: 0.4546 - val_mae: 0.5629 - val_rmse: 0.6743
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4614 - mae: 0.5661 - rmse: 0.6792 - val_loss: 0.4361 - val_mae: 0.5527 - val_rmse: 0.6604
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4499 - mae: 0.5604 - rmse: 0.6707 - val_loss: 0.4242 - val_mae: 0.5464 - val_rmse: 0.6513
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4383 - mae: 0.5531 - rmse: 0.6621 - val_loss: 0.4202 - val_mae: 0.5436 - val_rmse: 0.6483
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4283 - mae: 0.5458 - rmse: 0.6544 - val_loss: 0.4200 - val_mae: 0.5425 - val_rmse: 0.6481
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4105 - mae: 0.5339 - rmse: 0.6407 - val_loss: 0.4110 - val_mae: 0.5370 - val_rmse: 0.6411
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3915 - mae: 0.5197 - rmse: 0.6257 - val_loss: 0.4002 - val_mae: 0.5303 - val_rmse: 0.6326
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3782 - mae: 0.5091 - rmse: 0.6150 - val_loss: 0.3951 - val_mae: 0.5248 - val_rmse: 0.6285
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3531 - mae: 0.4909 - rmse: 0.5942 - val_loss: 0.3886 - val_mae: 0.5188 - val_rmse: 0.6233
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1556 - mae: 0.3138 - rmse: 0.3945 - val_loss: 0.2003 - val_mae: 0.3680 - val_rmse: 0.4475
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1537 - mae: 0.3103 - rmse: 0.3921 - val_loss: 0.1918 - val_mae: 0.3631 - val_rmse: 0.4380
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1562 - mae: 0.3132 - rmse: 0.3952 - val_loss: 0.2064 - val_mae: 0.3798 - val_rmse: 0.4543
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1524 - mae: 0.3104 - rmse: 0.3904 - val_loss: 0.2055 - val_mae: 0.3743 - val_rmse: 0.4533
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1522 - mae: 0.3096 - rmse: 0.3901 - val_loss: 0.2040 - val_mae: 0.3751 - val_rmse: 0.4517
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1530 - mae: 0.3101 - rmse: 0.3912 - val_loss: 0.1999 - val_mae: 0.3722 - val_rmse: 0.4472
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1466 - mae: 0.3042 - rmse: 0.3829 - val_loss: 0.2037 - val_mae: 0.3753 - val_rmse: 0.4514
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 38.
# Selected epoch: 38 (min val_loss)
# Valid @ sel —  MAE: 0.3631 | RMSE: 0.438 (scaled)
# Train @ sel —  MAE: 0.3122  | RMSE: 0.3929 (scaled)
# Test RMSE (avg over all steps): 0.476 (scaled)
# Test  MAE (avg over all steps): 0.383 (scaled)
# Per-horizon (0 = 1-step ahead):
#   MAE : [0.268 0.325 0.374 0.386 0.417 0.435 0.45  0.464 0.453 0.439 0.421 0.411
#  0.393 0.384 0.368 0.372 0.349 0.365 0.361 0.362 0.342 0.343 0.354 0.344]
#   RMSE: [0.364 0.419 0.469 0.486 0.5   0.523 0.531 0.552 0.535 0.523 0.505 0.505
#  0.481 0.473 0.46  0.484 0.458 0.468 0.461 0.453 0.433 0.431 0.437 0.429]

# %%
week_1_hour_2_model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

# Train baseline model with different lookback and horizon
train_and_test(week_1_hour_2_model,title="Baseline Model w/ 2 hour horizon and 1 week window",verbose=1)

# Evaluate the newly trained model
evaluate_on_test(week_1_hour_2_model, plot_last_hours=24*7)
# Out:
# Baseline Model w/ 2 hour horizon and 1 week window
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.8545 - mae: 0.7496 - rmse: 0.9211 - val_loss: 0.4048 - val_mae: 0.5447 - val_rmse: 0.6362
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4398 - mae: 0.5587 - rmse: 0.6630 - val_loss: 0.3969 - val_mae: 0.5239 - val_rmse: 0.6300
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.3725 - mae: 0.5181 - rmse: 0.6102 - val_loss: 0.3422 - val_mae: 0.4850 - val_rmse: 0.5850
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.3134 - mae: 0.4675 - rmse: 0.5596 - val_loss: 0.2587 - val_mae: 0.4276 - val_rmse: 0.5087
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.2455 - mae: 0.4068 - rmse: 0.4954 - val_loss: 0.1926 - val_mae: 0.3711 - val_rmse: 0.4389
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1826 - mae: 0.3441 - rmse: 0.4272 - val_loss: 0.1599 - val_mae: 0.3399 - val_rmse: 0.3999
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1618 - mae: 0.3200 - rmse: 0.4020 - val_loss: 0.1237 - val_mae: 0.2980 - val_rmse: 0.3517
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1371 - mae: 0.2924 - rmse: 0.3701 - val_loss: 0.1088 - val_mae: 0.2770 - val_rmse: 0.3299
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1174 - mae: 0.2689 - rmse: 0.3426 - val_loss: 0.0915 - val_mae: 0.2507 - val_rmse: 0.3026
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0361 - mae: 0.1466 - rmse: 0.1900 - val_loss: 0.0389 - val_mae: 0.1262 - val_rmse: 0.1972
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Selected epoch: 30 (min val_loss)
# Valid @ sel —  MAE: 0.128 | RMSE: 0.1923 (scaled)
# Train @ sel —  MAE: 0.1568  | RMSE: 0.2043 (scaled)
# Test RMSE (avg over all steps): 0.166 (scaled)
# Test  MAE (avg over all steps): 0.122 (scaled)
# Per-horizon (0 = 1-step ahead):
#   MAE : [0.084 0.161]
#   RMSE: [0.109 0.207]

# %% [markdown]
# ### Graded Questions

# %%
# Set a1 to the Validation MAE at the epoch of minimum validation loss (mse) for your best choices of lookback and horizon

a1a = 0.1021            # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a1a = {a1a:.4f}')
# Out:
# a1a = 0.1021

# %% [markdown]
# #### Question a1b: Describe below your experiments. What effect did your changes to the lookback and horizon have? Did you get an improvement in the validation MAE?
#
# #### Your Answer Here: The best performing model was the baseline. When adding horizon to the data processing, the validation performance dropped dramatically. As stated in the descrption above the processing cell, for horizon > 1 you will get overlapping predictions and hence horizon predictions for almost all step; these are averaged to produce the actual predicted  y^. Strecthing the window of operation also didn't imporve performance of the models. The experiments included a 2 week lookback, a 24 hour horizon, and a 2 hour horizon.

# %% [markdown]
# ## Problem Two — Architectural Tweaks
#
# Using the best lookback and horizon from Problem 1 (or the original defaults if they performed better),
# experiment with at least **one architectural change**.
#
# Possible options:
# - Add a deeper “head” (e.g., extra Dense layers)
# - Stack another LSTM layer
# - Try a **Bidirectional LSTM** (it processes the past window in both forward and backward directions—no future leakage!)
#
# Train, evaluate, and answer the graded questions.

# %%
# Deeper "head" to baseline LSTM model
deep_head_model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32),
    Dropout(0.2),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(64, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

# Train the deep head model
train_and_test(deep_head_model,title="Deep Head Model",verbose=1)

# Evaluate the deep head model
evaluate_on_test(deep_head_model, plot_last_hours=24*7)
# Out:
# Deep Head Model
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.7375 - mae: 0.6956 - rmse: 0.8534 - val_loss: 0.3463 - val_mae: 0.4946 - val_rmse: 0.5885
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3574 - mae: 0.5112 - rmse: 0.5971 - val_loss: 0.2823 - val_mae: 0.4451 - val_rmse: 0.5313
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.2728 - mae: 0.4403 - rmse: 0.5218 - val_loss: 0.1726 - val_mae: 0.3504 - val_rmse: 0.4154
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1921 - mae: 0.3656 - rmse: 0.4379 - val_loss: 0.0889 - val_mae: 0.2570 - val_rmse: 0.2981
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1290 - mae: 0.2897 - rmse: 0.3591 - val_loss: 0.0694 - val_mae: 0.2288 - val_rmse: 0.2634
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1018 - mae: 0.2592 - rmse: 0.3188 - val_loss: 0.0570 - val_mae: 0.2049 - val_rmse: 0.2388
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0893 - mae: 0.2351 - rmse: 0.2988 - val_loss: 0.0561 - val_mae: 0.2025 - val_rmse: 0.2369
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0810 - mae: 0.2272 - rmse: 0.2844 - val_loss: 0.0458 - val_mae: 0.1788 - val_rmse: 0.2141
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0669 - mae: 0.2071 - rmse: 0.2586 - val_loss: 0.0362 - val_mae: 0.1535 - val_rmse: 0.1903
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0592 - mae: 0.1940 - rmse: 0.2431 - val_loss: 0.0336 - val_mae: 0.1471 - val_rmse: 0.1832
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0547 - mae: 0.1861 - rmse: 0.2336 - val_loss: 0.0321 - val_mae: 0.1429 - val_rmse: 0.1790
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0480 - mae: 0.1703 - rmse: 0.2190 - val_loss: 0.0284 - val_mae: 0.1307 - val_rmse: 0.1686
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0439 - mae: 0.1632 - rmse: 0.2094 - val_loss: 0.0247 - val_mae: 0.1198 - val_rmse: 0.1572
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0391 - mae: 0.1544 - rmse: 0.1978 - val_loss: 0.0239 - val_mae: 0.1214 - val_rmse: 0.1547
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0363 - mae: 0.1497 - rmse: 0.1905 - val_loss: 0.0222 - val_mae: 0.1142 - val_rmse: 0.1490
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0330 - mae: 0.1425 - rmse: 0.1818 - val_loss: 0.0203 - val_mae: 0.1075 - val_rmse: 0.1425
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0300 - mae: 0.1348 - rmse: 0.1733 - val_loss: 0.0193 - val_mae: 0.1033 - val_rmse: 0.1391
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0283 - mae: 0.1319 - rmse: 0.1681 - val_loss: 0.0190 - val_mae: 0.0993 - val_rmse: 0.1379
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0271 - mae: 0.1285 - rmse: 0.1646 - val_loss: 0.0219 - val_mae: 0.1080 - val_rmse: 0.1478
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0248 - mae: 0.1226 - rmse: 0.1573 - val_loss: 0.0172 - val_mae: 0.0940 - val_rmse: 0.1312
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0233 - mae: 0.1186 - rmse: 0.1528 - val_loss: 0.0165 - val_mae: 0.0886 - val_rmse: 0.1285
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0240 - mae: 0.1203 - rmse: 0.1548 - val_loss: 0.0175 - val_mae: 0.0950 - val_rmse: 0.1325
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0228 - mae: 0.1176 - rmse: 0.1510 - val_loss: 0.0168 - val_mae: 0.0916 - val_rmse: 0.1295
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0217 - mae: 0.1139 - rmse: 0.1474 - val_loss: 0.0170 - val_mae: 0.0902 - val_rmse: 0.1304
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0215 - mae: 0.1153 - rmse: 0.1465 - val_loss: 0.0173 - val_mae: 0.0940 - val_rmse: 0.1315
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0200 - mae: 0.1098 - rmse: 0.1414 - val_loss: 0.0175 - val_mae: 0.0943 - val_rmse: 0.1321
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 21.
# Selected epoch: 21 (min val_loss)
# Valid @ sel —  MAE: 0.08856 | RMSE: 0.1285 (scaled)
# Train @ sel —  MAE: 0.1165  | RMSE: 0.1507 (scaled)
# Test RMSE (avg over all steps): 0.096 (scaled)
# Test  MAE (avg over all steps): 0.078 (scaled)

# %%
# Stacked LSTM to baseline LSTM model
stacked_lstm_model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32, return_sequences=True), # Return sequences for the next LSTM layer
    Dropout(0.2),
    LSTM(32), # Add another LSTM layer
    Dropout(0.1),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

# Train the stacked lstm model
train_and_test(stacked_lstm_model,title="Stacked LSTM Model",verbose=1)

# Evaluate the stacked lstm model
evaluate_on_test(stacked_lstm_model, plot_last_hours=24*7)
# Out:
# Stacked LSTM Model
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.7201 - mae: 0.6922 - rmse: 0.8441 - val_loss: 0.4860 - val_mae: 0.5788 - val_rmse: 0.6972
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4648 - mae: 0.5791 - rmse: 0.6813 - val_loss: 0.4130 - val_mae: 0.5419 - val_rmse: 0.6427
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4145 - mae: 0.5472 - rmse: 0.6432 - val_loss: 0.3823 - val_mae: 0.5193 - val_rmse: 0.6183
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3159 - mae: 0.4724 - rmse: 0.5614 - val_loss: 0.2524 - val_mae: 0.4357 - val_rmse: 0.5024
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2302 - mae: 0.3957 - rmse: 0.4796 - val_loss: 0.1581 - val_mae: 0.3454 - val_rmse: 0.3977
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1836 - mae: 0.3505 - rmse: 0.4282 - val_loss: 0.1007 - val_mae: 0.2738 - val_rmse: 0.3173
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1359 - mae: 0.2976 - rmse: 0.3685 - val_loss: 0.0583 - val_mae: 0.2054 - val_rmse: 0.2415
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1041 - mae: 0.2588 - rmse: 0.3226 - val_loss: 0.0493 - val_mae: 0.1880 - val_rmse: 0.2220
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0835 - mae: 0.2326 - rmse: 0.2890 - val_loss: 0.0359 - val_mae: 0.1512 - val_rmse: 0.1895
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0223 - mae: 0.1159 - rmse: 0.1493 - val_loss: 0.0160 - val_mae: 0.0884 - val_rmse: 0.1263
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0208 - mae: 0.1135 - rmse: 0.1441 - val_loss: 0.0178 - val_mae: 0.0997 - val_rmse: 0.1335
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0232 - mae: 0.1187 - rmse: 0.1523 - val_loss: 0.0174 - val_mae: 0.0939 - val_rmse: 0.1319
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0192 - mae: 0.1084 - rmse: 0.1384 - val_loss: 0.0156 - val_mae: 0.0805 - val_rmse: 0.1248
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0224 - mae: 0.1164 - rmse: 0.1495 - val_loss: 0.0170 - val_mae: 0.0925 - val_rmse: 0.1303
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0208 - mae: 0.1115 - rmse: 0.1443 - val_loss: 0.0147 - val_mae: 0.0833 - val_rmse: 0.1212
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0205 - mae: 0.1106 - rmse: 0.1432 - val_loss: 0.0169 - val_mae: 0.0873 - val_rmse: 0.1299
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0205 - mae: 0.1123 - rmse: 0.1432 - val_loss: 0.0150 - val_mae: 0.0860 - val_rmse: 0.1226
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0192 - mae: 0.1085 - rmse: 0.1384 - val_loss: 0.0142 - val_mae: 0.0793 - val_rmse: 0.1192
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0195 - mae: 0.1064 - rmse: 0.1396 - val_loss: 0.0139 - val_mae: 0.0820 - val_rmse: 0.1181
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0199 - mae: 0.1092 - rmse: 0.1409 - val_loss: 0.0160 - val_mae: 0.0888 - val_rmse: 0.1267
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0190 - mae: 0.1089 - rmse: 0.1377 - val_loss: 0.0156 - val_mae: 0.0860 - val_rmse: 0.1249
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0182 - mae: 0.1055 - rmse: 0.1348 - val_loss: 0.0156 - val_mae: 0.0857 - val_rmse: 0.1247
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0167 - mae: 0.0999 - rmse: 0.1290 - val_loss: 0.0157 - val_mae: 0.0840 - val_rmse: 0.1251
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0197 - mae: 0.1085 - rmse: 0.1402 - val_loss: 0.0144 - val_mae: 0.0842 - val_rmse: 0.1201
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 43.
# Selected epoch: 43 (min val_loss)
# Valid @ sel —  MAE: 0.08195 | RMSE: 0.1181 (scaled)
# Train @ sel —  MAE: 0.1067  | RMSE: 0.1392 (scaled)
# Test RMSE (avg over all steps): 0.087 (scaled)
# Test  MAE (avg over all steps): 0.072 (scaled)

# %%
# Bidirectional LSTM to baseline LSTM model
bidirectional_lstm_model = Sequential([
    Input(shape=(lookback, 1)),
    Bidirectional(LSTM(32, return_sequences=True)), # Bidirectional wrapper
    Dropout(0.2),
    Bidirectional(LSTM(32)), # Add another Bidirectional LSTM layer
    Dropout(0.1),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon)
])

# Train the bidirectional lstm model
train_and_test(bidirectional_lstm_model,title="Bidirectional LSTM Model",verbose=1)

# Evaluate the bidirectional lstm model
evaluate_on_test(bidirectional_lstm_model, plot_last_hours=24*7)
# Out:
# Bidirectional LSTM Model
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 0.5921 - mae: 0.6246 - rmse: 0.7647 - val_loss: 0.2774 - val_mae: 0.4592 - val_rmse: 0.5267
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.2446 - mae: 0.4142 - rmse: 0.4937 - val_loss: 0.1546 - val_mae: 0.3414 - val_rmse: 0.3932
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.1534 - mae: 0.3194 - rmse: 0.3914 - val_loss: 0.0857 - val_mae: 0.2463 - val_rmse: 0.2928
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0211 - mae: 0.1119 - rmse: 0.1454 - val_loss: 0.0210 - val_mae: 0.1070 - val_rmse: 0.1451
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0212 - mae: 0.1146 - rmse: 0.1455 - val_loss: 0.0202 - val_mae: 0.1025 - val_rmse: 0.1422
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0205 - mae: 0.1107 - rmse: 0.1431 - val_loss: 0.0191 - val_mae: 0.0992 - val_rmse: 0.1383
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0209 - mae: 0.1135 - rmse: 0.1445 - val_loss: 0.0216 - val_mae: 0.1096 - val_rmse: 0.1471
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0192 - mae: 0.1073 - rmse: 0.1387 - val_loss: 0.0182 - val_mae: 0.0949 - val_rmse: 0.1349
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0200 - mae: 0.1100 - rmse: 0.1413 - val_loss: 0.0189 - val_mae: 0.0996 - val_rmse: 0.1376
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0193 - mae: 0.1071 - rmse: 0.1387 - val_loss: 0.0198 - val_mae: 0.1030 - val_rmse: 0.1406
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0197 - mae: 0.1091 - rmse: 0.1404 - val_loss: 0.0181 - val_mae: 0.0959 - val_rmse: 0.1346
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0191 - mae: 0.1060 - rmse: 0.1380 - val_loss: 0.0235 - val_mae: 0.1144 - val_rmse: 0.1531
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0185 - mae: 0.1067 - rmse: 0.1360 - val_loss: 0.0199 - val_mae: 0.1025 - val_rmse: 0.1411
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 33.
# Selected epoch: 36 (min val_loss)
# Valid @ sel —  MAE: 0.09588 | RMSE: 0.1346 (scaled)
# Train @ sel —  MAE: 0.1069  | RMSE: 0.1377 (scaled)
# Test RMSE (avg over all steps): 0.115 (scaled)
# Test  MAE (avg over all steps): 0.087 (scaled)

# %% [markdown]
# ### Graded Questions

# %%
# Set a1 to the Validation MAE at the epoch of minimum validation loss (mse)

a2a = 0.08195           # Replace 0.0 with your answer

# %%
# Graded Answer
# DO NOT change this cell in any way

print(f'a2a = {a2a:.4f}')
# Out:
# a2a = 0.0819

# %% [markdown]
# #### Question a2b: Describe below your experiments and what you observed. Did you get a better validation MAE through architectural changes?
#
# #### Your Answer Here:

# %% [markdown]
# ## Problem Three — Autoregressive Forecasting (ChatGPT Discussion)
#
# In this final problem, you’ll explore **autoregressive forecasting**, where the model predicts one step ahead and feeds that prediction back as input to generate the next step.
#
# **Your task:**
# 1. Briefly describe your current model to ChatGPT (e.g., “My LSTM predicts the next 24 hours directly from the past 168 hours.”), or share a short code snippet.
# 2. Ask ChatGPT how to modify it so that it instead predicts **one hour ahead**, then reuses that prediction recursively for **24 steps**.
# 3. Implement or outline the version it suggests.
# 4. Answer the graded question.

# %%
# Stacked LSTM to baseline LSTM model
autoregressive_stacked_lstm_model = Sequential([
    Input(shape=(lookback, 1)),
    LSTM(32, return_sequences=True), # Return sequences for the next LSTM layer
    Dropout(0.2),
    LSTM(32), # Add another LSTM layer
    Dropout(0.1),
    Dense(16, activation="relu", kernel_initializer=hn),
    Dense(horizon) # This will output a single value (horizon=1)
])

# Compile and train this model (you would run train_and_test here)
train_and_test(autoregressive_stacked_lstm_model, title="Autoregressive Stacked LSTM (Training)", verbose=1)
# Assuming you have trained autoregressive_stacked_lstm_model
# Out:
# Autoregressive Stacked LSTM (Training)
#
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.7063 - mae: 0.6840 - rmse: 0.8363 - val_loss: 0.4928 - val_mae: 0.5795 - val_rmse: 0.7020
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4593 - mae: 0.5795 - rmse: 0.6773 - val_loss: 0.4180 - val_mae: 0.5429 - val_rmse: 0.6465
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.4235 - mae: 0.5523 - rmse: 0.6503 - val_loss: 0.3764 - val_mae: 0.5180 - val_rmse: 0.6135
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3523 - mae: 0.5046 - rmse: 0.5929 - val_loss: 0.2736 - val_mae: 0.4494 - val_rmse: 0.5230
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.2567 - mae: 0.4222 - rmse: 0.5062 - val_loss: 0.1551 - val_mae: 0.3436 - val_rmse: 0.3938
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1749 - mae: 0.3399 - rmse: 0.4178 - val_loss: 0.0957 - val_mae: 0.2664 - val_rmse: 0.3093
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1223 - mae: 0.2835 - rmse: 0.3497 - val_loss: 0.0733 - val_mae: 0.2291 - val_rmse: 0.2708
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0939 - mae: 0.2450 - rmse: 0.3063 - val_loss: 0.0597 - val_mae: 0.2029 - val_rmse: 0.2444
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0236 - mae: 0.1202 - rmse: 0.1535 - val_loss: 0.0183 - val_mae: 0.0988 - val_rmse: 0.1354
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0241 - mae: 0.1228 - rmse: 0.1552 - val_loss: 0.0190 - val_mae: 0.1032 - val_rmse: 0.1380
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0239 - mae: 0.1220 - rmse: 0.1546 - val_loss: 0.0209 - val_mae: 0.1058 - val_rmse: 0.1447
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0240 - mae: 0.1217 - rmse: 0.1550 - val_loss: 0.0181 - val_mae: 0.0946 - val_rmse: 0.1344
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0218 - mae: 0.1146 - rmse: 0.1475 - val_loss: 0.0190 - val_mae: 0.0988 - val_rmse: 0.1378
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0228 - mae: 0.1164 - rmse: 0.1510 - val_loss: 0.0195 - val_mae: 0.1020 - val_rmse: 0.1397
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0222 - mae: 0.1149 - rmse: 0.1491 - val_loss: 0.0220 - val_mae: 0.1091 - val_rmse: 0.1483
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0224 - mae: 0.1160 - rmse: 0.1496 - val_loss: 0.0190 - val_mae: 0.0972 - val_rmse: 0.1379
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0191 - mae: 0.1073 - rmse: 0.1383 - val_loss: 0.0210 - val_mae: 0.1038 - val_rmse: 0.1449
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 36.
# Selected epoch: 36 (min val_loss)
# Valid @ sel —  MAE: 0.09461 | RMSE: 0.1344 (scaled)
# Train @ sel —  MAE: 0.1212  | RMSE: 0.1552 (scaled)

# %%
# Implement autoregressive prediction for the next 24 hours
# We will use the trained autoregressive_stacked_lstm_model from the previous cell

# Number of steps to predict recursively
steps = 24

# Get the last 'lookback' hours from the training or validation set to start the forecast
# We'll use the last window from the validation set for this example, as it precedes the test set
# Ensure lookback is less than or equal to the number of samples in X_val
initial_input = X_val[-1, :, :].copy() # Shape (lookback, 1)

# Prepare the input for the recursive prediction loop
current_input = initial_input.reshape(1, lookback, 1) # Shape (1, lookback, 1) for model input

# Store the recursive predictions
recursive_predictions_scaled = []

# Loop to predict the next 'steps' hours
for _ in range(steps):
    # Predict the next hour (horizon=1)
    predicted_next_hour_scaled = autoregressive_stacked_lstm_model.predict(current_input, verbose=0)[0, 0]

    # Append the prediction to the input sequence for the next step
    # Remove the oldest data point and add the new prediction
    current_input = np.roll(current_input, -1, axis=1)
    current_input[0, -1, 0] = predicted_next_hour_scaled

    # Store the prediction
    recursive_predictions_scaled.append(predicted_next_hour_scaled)

recursive_predictions_scaled = np.array(recursive_predictions_scaled)

# Since we trained on scaled data, the predictions are also scaled.
# To evaluate and plot in original units, we need to invert the scaling.
# The scaler was fit on the training data (s6.iloc[:n_train])
# We need a scaler for the target variable (which is just the next hour in this case)
# Since the target was also scaled with the same scaler, we can reuse it.

# Invert scaling for recursive predictions
# The scaler expects input shape (n_samples, n_features)
recursive_predictions_original = scaler.inverse_transform(recursive_predictions_scaled.reshape(-1, 1)).flatten()

# Get the true values for comparison
# Find the index in the original scaled test_x array corresponding to the start of the forecast
# The forecasts start immediately after the last window used for validation.
# The last window in X_val ends at index len(val_x) - 1 in the scaled validation data.
# This corresponds to index n_train + len(val_x) - 1 in the scaled s6 array.
# The first true value for the recursive forecast will be at the next index.
forecast_start_index_in_s6 = n_train + len(val_x)

# Ensure we don't go out of bounds of s6
true_forecast_end_index_in_s6 = min(forecast_start_index_in_s6 + steps, len(s6))
true_forecast_values_original = s6.iloc[forecast_start_index_in_s6 : true_forecast_end_index_in_s6].values

# If the predicted steps are more than available true test steps, truncate predictions
if len(recursive_predictions_original) > len(true_forecast_values_original):
    recursive_predictions_original = recursive_predictions_original[:len(true_forecast_values_original)]

# Calculate MAE and RMSE in original units for the recursive forecast
err_original = recursive_predictions_original - true_forecast_values_original
recursive_mae = np.mean(np.abs(err_original))
recursive_rmse = np.sqrt(np.mean(err_original**2))


print(f"Recursive Forecast ({steps} steps):")
print(f"  MAE: {recursive_mae:,.3f} MW")
print(f"  RMSE: {recursive_rmse:,.3f} MW")


# Plot the recursive forecast vs the true values
plt.figure(figsize=(14, 6))
plt.title(f"Recursive Forecast ({steps} steps) vs Truth (Original Units)")

# Plot the historical input data leading up to the forecast start for context
historical_input_original = scaler.inverse_transform(initial_input).flatten()
historical_indices = np.arange(-lookback, 0) # Indices relative to the forecast start

plt.plot(historical_indices, historical_input_original, label="Historical Input (Truth)")

# Plot the true future values
future_indices = np.arange(0, len(true_forecast_values_original))
plt.plot(future_indices, true_forecast_values_original, label="True Future")

# Plot the recursive predictions
plt.plot(future_indices, recursive_predictions_original, label="Recursive Predicted", linestyle="--")


plt.xlabel("Hours relative to forecast start")
plt.ylabel("MW")
plt.grid(True, axis='y', linestyle=':', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Recursive Forecast (24 steps):
#   MAE: 892.113 MW
#   RMSE: 1,020.150 MW

# %% [markdown]
# ### Graded Questions

# %% [markdown]
# #### Question a3: Answer the graded questions comparing the recursive and direct approaches:
#    - Does the error grow with horizon in the autoregressive version?
#    - Which approach you tried in this homework performs better overall?
#
# #### Your Answer Here: As the horizon grows, the error seems to grow farther away from the truth future. The best approach from the hw was the stacked lstm model where an additional 32 layer was input along with a dropout set of (0.1).

# %%
print_results()
# Out:
# Stacked LSTM Model                   val_RMSE@min_val_loss=0.1181 | val_MAE@min_val_loss=0.08195 | epoch=43  (scaled)
# Deep Head Model                      val_RMSE@min_val_loss=0.1285 | val_MAE@min_val_loss=0.08856 | epoch=21  (scaled)
# Baseline Model w/ 2 hour horizon and 2 week window  val_RMSE@min_val_loss=0.1303 | val_MAE@min_val_loss=0.07767 | epoch=7  (scaled)
# Baseline Model                       val_RMSE@min_val_loss=0.1313 | val_MAE@min_val_loss=0.09242 | epoch=19  (scaled)
# Baseline Model w/ 12 hour horizon and 2 week window  val_RMSE@min_val_loss=0.1322 | val_MAE@min_val_loss=0.08156 | epoch=2  (scaled)
# Autoregressive Stacked LSTM (Training)  val_RMSE@min_val_loss=0.1344 | val_MAE@min_val_loss=0.09461 | epoch=36  (scaled)
# Bidirectional LSTM Model             val_RMSE@min_val_loss=0.1346 | val_MAE@min_val_loss=0.09588 | epoch=36  (scaled)
# Baseline Model w/ 2 week window      val_RMSE@min_val_loss=0.1504 | val_MAE@min_val_loss=0.1021 | epoch=25  (scaled)
# Baseline Model w/ 2 hour horizon and 1 week window  val_RMSE@min_val_loss=0.1923 | val_MAE@min_val_loss=0.128 | epoch=30  (scaled)
# Baseline Model w/ 24 hour horizon    val_RMSE@min_val_loss=0.438 | val_MAE@min_val_loss=0.3631 | epoch=38  (scaled)
